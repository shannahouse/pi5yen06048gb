# %%
from google import genai

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，答案在於**太陽光**與**地球大氣層**之間的互動。這個物理現象被稱為**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成以下幾個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有顏色的光。
# * 這些光以「波」的形式傳播。
# * **紅色光**的波長最長（像平緩的大浪）。
# * **藍色和紫色光**的波長最短（像急促的小波浪）。
#
# ### 2. 大氣層像是一個篩子
# 當太陽光穿過太空進入地球大氣層時，會碰到大氣中的氣體分子（主要是氮氣和氧氣）。
# * 這些氣體分子的體積非常小，比光的波長還要小。
#
# ### 3. 「瑞利散射」發生了
# 當光線碰到這些微小的氣體分子時，就會產生散射（往四面八方彈射）：
# * 波長較長的紅光、黃光穿透力強，能直接穿透大氣層，幾乎不受影響。
# * **波長較短的藍光、紫光，碰到氣體分子時，就會像彈珠一樣被瘋狂地向四面八方彈射（散射）。**
# * 這些被散射的藍光充滿了整個天空，當我們抬頭看時，就會看到滿天的藍光。
#
# ---
#
# ### 常見疑問：那為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短，被散射得更厲害，為什麼天空看起來是藍色而不是紫色？
#
# 原因有兩個：
# 1. **太陽光的組成：** 太陽放射出的光芒中，藍光的比例本來就比紫色光多很多。
# 2. **人類眼睛的構造：** 人類眼睛對藍色比對紫色敏感得多。我們的視網膜對「藍、綠、紅」三種顏色最敏感，大腦會自動忽略較弱的紫色訊號，將天空呈現為明亮的藍色。
#
# ---
#
# ### 補充：為什麼黃昏（夕陽）是紅色的？
# 到了傍晚，太陽下山，陽光是「斜射」進入我們的眼睛。這時，陽光穿過大氣層的距離，比中午時整整長了許多。
#
# 因為距離太長，**藍光在到達我們眼睛之前，就已經在半路被散射光了**；只剩下穿透力最強、波長最長的**紅光和橙光**能夠穿透厚厚的大氣層，到達我們的眼睛，所以夕陽看起來就是美麗的紅橙色了。
