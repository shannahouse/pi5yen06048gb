# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以呈現藍色，主要是因為**「太陽光」**與**「地球大氣層」**之間產生的一種物理現象，這個現象被稱為**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 陽光其實是彩色的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有彩虹的顏色混合而成的。這些光以「波」的形式傳播：
# *   **紅色光**的波長最長，能量較弱。
# *   **藍色和紫色光**的波長最短，能量較強。
#
# ### 2. 大氣層的「阻擋」作用
# 當太陽光穿過地球的大氣層時，會碰到大氣中的氣體分子（主要是氮氣和氧氣）以及微小的塵埃。
# *   波長較長的**紅光、黃光**穿透力強，能直接穿透這些微小的分子，直達地面。
# *   波長較短的**藍光**在碰到這些微小的氣體分子時，會像乒乓球撞到牆壁一樣，**向四面八方散射開來**。這些被散射的藍光充滿了整個天空，並進入我們的眼睛，所以我們抬頭看天空時，就會覺得天空是藍色的。
#
# ---
#
# ### 💡 常見疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光更短，理論上散射得更厲害，那為什麼天空不是紫色的呢？主要有兩個原因：
#
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類視網膜上的感光細胞（錐狀細胞）對**藍色、綠色和紅色**非常敏感，但對紫色的敏感度很低。因此，大腦在接收到光線訊號後，會自動把天空「解讀」成藍色。
#
# ---
#
# ### 延伸思考：為什麼傍晚的夕陽是「紅色」的？
# 到了傍晚，太陽角度變低，陽光必須穿過**比中午厚上許多倍**的大氣層才能到達我們的眼睛。
#
# 在這個漫長的路徑中，絕大多數的藍光在半路就已經被散射光了，根本無法到達我們的眼睛。此時，只有穿透力最強、最不容易被散射的**紅光和橙光**能穿透重重障礙到達我們眼前，因此夕陽和晚霞就呈現出美麗的橘紅色。

# %% [raw]
# print("hello word???")

# %%
print("hello word")
# Out:
# hello word

# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="為何樹莓派這麼麻煩"
)

print(interaction.output_text)
# Out:
# 哈哈，完全理解你的感受！無數人在剛接觸樹莓派（Raspberry Pi）時，都會發出一樣的吶喊：「為什麼這東西這麼麻煩？」
#
# 樹莓派之所以讓人覺得「麻煩」，主要是因為它的**定位、硬體設計和作業系統**與我們習慣的微軟 Windows 或蘋果 macOS/iOS 截然不同。
#
# 以下為你拆解為什麼樹莓派會這麼「折磨人」的五大原因，以及如何讓它變得不那麼麻煩：
#
# ### 1. 它的定位是「開發與教育工具」，而非「消費級產品」
# *   **一般電腦/手機：** 廠商已經把所有的硬體、軟體、驅動程式都包裝好了，你只要開機、點擊、使用。
# *   **樹莓派：** 它的初衷是為了讓學生和工程師「學習電腦底層、程式設計和電子DIY」。它故意保留了許多「未完成」的狀態，**因為「解決麻煩」的過程，就是學習的過程。** 它是樂高積木，不是現成的玩具汽車。
#
# ### 2. Linux 系統的學習曲線（命令行地獄）
# 大多數人習慣了圖形介面（GUI），但在樹莓派上，你常常需要面對黑底白字的「終端機（Terminal）」。
# *   裝個軟體不能只點「下一步」，得輸入 `sudo apt update && sudo apt install ...`。
# *   權限設定嚴格，動不動就出現 `Permission denied`（權限不足）。
# *   一旦指令打錯一個字，整個系統可能就崩潰或毫無反應。
#
# ### 3. 硬體「拼圖式」的脆弱生態
# 樹莓派買來通常只是「一片裸板」，你得自己準備：
# *   **SD 卡：** 這是樹莓派最大的硬體硬傷。SD 卡讀寫壽命有限，一旦異常斷電，極容易**系統損壞（Corrupted）**，導致無法開機，你得重灌。
# *   **電源要求極高：** 樹莓派對電壓非常敏感。隨便拿個手機充電頭，常常會因為電壓不足（Under-voltage）導致系統降頻或莫名重啟。
# *   **沒有電源鍵（早期型號）：** 拔插頭關機容易壞系統，必須用指令 `sudo shutdown now` 關機，對新手很不直觀。
#
# ### 4. ARM 架構與 x86 的相容性問題
# 我們一般 PC 用的是 Intel/AMD 的 x86 架構，而樹莓派用的是手機常見的 ARM 架構。
# *   這意味著你**不能**直接在樹莓派上執行一般的 Windows 軟體（如常見的 `.exe` 檔）。
# *   雖然現在支援 ARM 的軟體變多了，但有時你還是得自己「下載原始碼來編譯」，這對新手來說簡直是天書。
#
# ### 5. 「開箱即用」的軟體極少
# 如果你想用樹莓派架設伺服器、軟路由、擋廣告系統（Pi-hole）或復古遊戲機：
# *   你必須自己燒錄系統、設定 IP、設定 SSH 連線、修改設定檔。
# *   網路上的教學文章常常因為「版本更新」而失效，照著做也可能失敗。
#
# ---
#
# ### 💡 如何降低樹莓派的「麻煩感」？
#
# 如果你已經買了，不想讓它吃灰，這裡有幾個減少折磨的「生存指南」：
#
# 1.  **使用 Raspberry Pi Imager：** 官方的燒錄軟體現在非常好用，可以在燒錄時就直接設定好 Wi-Fi、密碼和啟用 SSH，省去開機後的麻煩設定。
# 2.  **買個好的電源（最好是官方的）：** 90% 的莫名當機和紅燈閃爍，都是因為電源不穩。
# 3.  **改用 SSD 開機：** 樹莓派 4 和 5 都支援用 USB 外接 SSD 開機。用 SSD 代替 SD 卡，系統速度快十倍，而且「再也不怕異常斷電導致系統壞掉」。
# 4.  **善用 Docker：** 如果你要裝很多服務，學一下 Docker。它把軟體打包成像 APP 一樣，安裝和移除都只要一行指令，不會弄髒你的系統。
# 5.  **把 ChatGPT 當作你的 Linux 助手：** 現在遇到任何報錯，直接把錯誤訊息貼給 AI，它會直接告訴你該輸入什麼指令解決，效率比以前上網爬文快 100 倍。
#
# **總結：**
# 樹莓派的「麻煩」在於它把電腦的內部細節毫無保留地展現給你。如果你只是想要一台上網、看 YouTube 的電腦，買一台二手 Mini PC（如 Intel N100 迷你電腦）會比樹莓派便宜、好用且省心十倍。但如果你想享受「動手掌控一切」的成就感，樹莓派的麻煩就是它最迷人的地方。

# %%
## python數學運算

# %%
print("這次我的第一個函式")
print('這次我的第一個函式') #str
print(50) #int
print(50.0) #float
print("這是整數",50)
print("這是浮點數",50.666)
print("這是字串","robert")
print("這是布林值",True)
print("這是整數",False)

# %%
print(3 + 5)
print(3 + 5 + 10)
print( 3 + 5 * 2)
print((3 + 5) * 2)
print(99 ** 99)

# %%
print(int("5") + 5)

# %%
n = int(input("請輸入整數:"))
m = float(input("請輸入另一個數值"))
print(n, "*", m, "=",  n * m)
# Out:
# 請輸入整數: 5
# 請輸入另一個數值 5
# 5 * 5.0 = 25.0

# %%
import math

radius = float(input("請輸入半徑:"))
area = radius ** 2 * math.pi
print("半徑:", radius, ", 圓面積=", area)
# Out:
# 請輸入半徑: 6
# 半徑: 6.0 , 圓面積= 113.09733552923255
