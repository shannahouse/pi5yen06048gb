# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from google import genai
#       2
# ----> 3 client = genai.Client()
#       4
#       5 interaction = client.interactions.create(
#       6     model="gemini-3.5-flash",
#
# File ~/Documents/pi5yen06048gb/.venv/lib/python3.12/site-packages/google/genai/client.py:389, in Client.__init__(self, enterprise, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     386   else:
#     387     http_options = HttpOptions(base_url=base_url)
# --> 389 self._api_client = self._get_api_client(
#     390     vertexai=resolved_vertexai,
#     391     api_key=api_key,
#     392     credentials=credentials,
#     393     project=project,
#     394     location=location,
#     395     debug_config=self._debug_config,
#     396     http_options=http_options,
#     397 )
#     399 self._aio = AsyncClient(self._api_client)
#     400 self._models = Models(self._api_client)
#
# File ~/Documents/pi5yen06048gb/.venv/lib/python3.12/site-packages/google/genai/client.py:442, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     425 if debug_config and debug_config.client_mode in [
#     426     'record',
#     427     'replay',
#     428     'auto',
#     429 ]:
#     430   return ReplayApiClient(
#     431       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     432       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    439       http_options=http_options,
#     440   )
# --> 442 return BaseApiClient(
#     443     vertexai=vertexai,
#     444     api_key=api_key,
#     445     credentials=credentials,
#     446     project=project,
#     447     location=location,
#     448     http_options=http_options,
#     449 )
#
# File ~/Documents/pi5yen06048gb/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:831, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     829 else:  # Implicit initialization or missing arguments.
#     830   if not self.api_key:
# --> 831     raise ValueError(
#     832         'No API key was provided. Please pass a valid API key. Learn how to'
#     833         ' create an API key at'
#     834         ' https://ai.google.dev/gemini-api/docs/api-key.'
#     835     )
#     836   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     837   self._http_options.api_version = 'v1beta'
#
# ValueError: No API key was provided. Please pass a valid API key. Learn how to create an API key at https://ai.google.dev/gemini-api/docs/api-key.
